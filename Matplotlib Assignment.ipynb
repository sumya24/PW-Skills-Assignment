# %% [markdown]
# ## Q1: What is Matplotlib? Why is it used? Name five plots that can be plotted using the pyplot module of Matplotlib.

# %% [markdown]
# Answer:
# Matplotlib is a popular Python library used for data visualization. It allows us to create a variety of static, animated, and interactive plots.
# It is especially useful in Data Science to visually understand data distributions, patterns, and insights.
#
# Uses:
#
# Plotting 2D graphs and charts
#
# Customizing plots with titles, labels, colors, styles
#
# Easy integration with NumPy and Pandas
#
# Five plots you can create using matplotlib.pyplot:
#
# Line Plot
#
# Scatter Plot
#
# Bar Plot
#
# Histogram
#
# Box Plot

# %% [markdown]
# ## Q2: What is a scatter plot? Use the following code to generate data for x and y. Using this generated data plot a scatter plot.

# %%
import numpy as np
import matplotlib.pyplot as plt

np.random.seed(3)
x = 3 + np.random.normal(0, 2, 50)
y = 3 + np.random.normal(0, 2, len(x))

# Scatter Plot
plt.scatter(x, y)
plt.title('Scatter Plot Example')
plt.xlabel('X-axis values')
plt.ylabel('Y-axis values')
plt.show()

# %% [markdown]
# ## Q3: Why is the subplot() function used? Draw four line plots using the subplot() function.

# %% [markdown]
# Answer:
#
# The subplot() function in Matplotlib is used to plot multiple plots in a single figure. It helps in comparing different datasets side-by-side.

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.array([0, 1, 2, 3, 4, 5])
y1 = np.array([0, 100, 200, 300, 400, 500])
y2 = np.array([50, 20, 40, 20, 60, 70])
y3 = np.array([10, 20, 30, 40, 50, 60])
y4 = np.array([200, 350, 250, 550, 450, 150])

plt.figure(figsize=(10, 8))

plt.subplot(2, 2, 1)
plt.plot(x, y1)
plt.title("Line 1")

plt.subplot(2, 2, 2)
plt.plot(x, y2)
plt.title("Line 2")

plt.subplot(2, 2, 3)
plt.plot(x, y3)
plt.title("Line 3")

plt.subplot(2, 2, 4)
plt.plot(x, y4)
plt.title("Line 4")

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Q4: What is a bar plot? Why is it used? Using the following data plot a bar plot and a horizontal bar plot.

# %%
import numpy as np
import matplotlib.pyplot as plt

company = np.array(["Apple", "Microsoft", "Google", "AMD"])
profit = np.array([3000, 8000, 1000, 10000])

# Bar Plot
plt.bar(company, profit, color='skyblue')
plt.title('Company Profit - Bar Plot')
plt.xlabel('Company')
plt.ylabel('Profit')
plt.show()

# Horizontal Bar Plot
plt.barh(company, profit, color='lightgreen')
plt.title('Company Profit - Horizontal Bar Plot')
plt.xlabel('Profit')
plt.ylabel('Company')
plt.show()

# %% [markdown]
# ## Q5: What is a box plot? Why is it used? Using the following data plot a box plot.

# %%
import numpy as np
import matplotlib.pyplot as plt

box1 = np.random.normal(100, 10, 200)
box2 = np.random.normal(90, 20, 200)

data = [box1, box2]

plt.boxplot(data)
plt.title("Box Plot Example")
plt.xlabel("Dataset")
plt.ylabel("Values")
plt.xticks([1, 2], ['Box1', 'Box2'])
plt.grid(True)
plt.show()

# %% [markdown]
# Answer:
#
# A box plot (or box-and-whisker plot) is a graphical representation of the distribution of a dataset that shows the minimum, first quartile (Q1), median, third quartile (Q3), and maximum. It is used to detect outliers and visualize spread and skewness.
